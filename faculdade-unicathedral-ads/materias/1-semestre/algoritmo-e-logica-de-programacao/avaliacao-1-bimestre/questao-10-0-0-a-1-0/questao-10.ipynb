# %% [markdown]
# ### 10. Um dos papéis fundamentais de um algoritmo computacional é automatizar tarefas repetitivas e garantir consistência nos cálculos, especialmente em áreas como comércio e prestação de serviços.
# ### Um pequeno comércio deseja automatizar o registro de vendas aplicando descontos personalizados por produto, informados manualmente pelo atendente.
# ### Crie um algoritmo computacional que funcione da seguinte forma:
# ### 1. Solicite ao usuário a quantidade de produtos vendidos;
# ###  2. Para cada produto, colete:
# + + ### Preço original
# + + ### Porcentagem de desconto a ser aplicada
# ### 3. Calcule o preço com desconto para cada produto:
# ### **preço final preço original-(preço original desconto/100)**
# ### 4. Ao final, apresente o total das vendas com todos os descontos aplicados.
