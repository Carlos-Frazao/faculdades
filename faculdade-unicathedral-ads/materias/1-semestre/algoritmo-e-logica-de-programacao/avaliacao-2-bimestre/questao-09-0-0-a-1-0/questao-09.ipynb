# %% [markdown]
# ### 09. Um coordenador de curso deseja organizar as notas de 50 alunos em ordem crescente, para facilitar a análise de desempenho. Para isso, ele pediu que fosse criado um algoritmo em pseudocódigo que utilize o método de ordenação por troca. Vaja a pseudocódigo abaixo, que esté incompleto: Elabore o trecho do código que deve ser usado para ordenar p vetor notas em ordem crescente.
# ---------
