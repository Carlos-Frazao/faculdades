# %% [markdown]
# ### 07. Uma empresa de comércio eletrônico mantém um sistema simples para registrar os códigos dos produtos vendidos em determinado período. O sistema armazena os códigos em um vetor e permite ao gerente verificar quantas vezes um determinado código foi vendido. Considere o trecho de pseudocódigo abaixo, que realiza essa contagem: Escreva o trecho do código que ser inserido na linha 14, que faça a busca pela variável valor procurado no vetor números e registre quantas vezes ele foi encontrado.
# ---------
