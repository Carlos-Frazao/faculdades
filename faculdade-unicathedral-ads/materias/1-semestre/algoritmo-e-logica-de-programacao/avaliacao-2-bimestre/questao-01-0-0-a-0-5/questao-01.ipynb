# %% [markdown]
# ### 01. No desenvolvimento de algoritmos estruturados, a definição correta da estrutura de dados é essencial para garantir a organização e a manipulação adequada das informações. Os velores são estruturas amplamente utilizadas quando se deseja armazenar vários elementos do mesmo tipo de forma sequencial. Com base nesse contexto e nos conceitos sobre vetores, assinale a alternativa correta:
#
# --------
# ### A.  Para armazenar diferentes tipos de dados em um mesmo vetor, como números e textos, é necessário declarar o vetor como tipo misto.
# ### B. O tipo do vetor deve ser definido após sua utilização, pois em pseudocódigo ele é automaticamente. atribuído
# ### C. Vetores devem ser declarados com tamanho fixo e tipo de dado específico, como vetor[1..10] de inteiro.
# ### D.  O uso de vetores é limitado a estruturas de repetição, sendo inválido acessá-los diretamente por índice.
# ### E. A declaração de um vetor permite o uso de indices alfanuméricos (ex: vetor["A".."Z"]) para facilitar a leitura do código.
# ### **Respostas corretas: (C)**
