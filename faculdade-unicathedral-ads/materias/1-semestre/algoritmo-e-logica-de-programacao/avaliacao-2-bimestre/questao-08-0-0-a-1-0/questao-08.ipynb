# %% [markdown]
# ### 07. Durante uma feira de ciências, os jurados digitam os códigos de 6 projetos que receberam destaque. O coordenador do evento deseja verificar se **algum código foi repetido**, o que indicaria erro na digitação ou avaliação duplicada. Veja o pseudocódigo abaixo, que está incompleto: Complete o trecho  faltando do dódigo com uma instrução que identifique dois valores do vetor são iguais e altere o valor da variável **duplicada**.
# ---------
