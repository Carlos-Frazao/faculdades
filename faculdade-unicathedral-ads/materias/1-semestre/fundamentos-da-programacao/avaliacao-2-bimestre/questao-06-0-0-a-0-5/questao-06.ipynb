# %% [markdown]
# ### Um estudante está desenvolvendo um programa que recebe dois números inteiros digitados pelo usuário e imprime a soma desses valores. Parte do programa ja está escrita, mas a definição da função que realiza a soma está faltando. Observe o trecho do programa:

# %%
# Função faltando aqui

def main():
    a = int(input("Digite o primeiro número: "))
    b = int(input("Digite o segundo número: "))
    resultado = somar(a, b)
    print("A soma é:", resultado)   

main()

# %% [markdown]
# ### Qual das opções abaixo completa cometamente c programa, garantindo que a função somar execute a soma dos dois números e retorne o resultado?
#
# ### A) def somar(x, y):
# ### ------print(x + y)
#
# ### B) def soma()
# ### ------return a b
#
# ### C) def somar(x, y):
# ### ------return x + y
#
# ### D) def somar(x, y):
# ### ------print("A soma é:", x + y)
#
# ### E) def somar(x, y)
# ### ------return x. y
#
# ### **Respostas corretas: (C)**
