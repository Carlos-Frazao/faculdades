# %% [markdown]
# ### 07. Um programa em Python foi construído para ler dois números digitados pelo usuário e exibir a soma deles. O programa foi dividido em duas funções, uma responsável, por ler os dados e outra por calcular e mostrar o resultado. No entanto, uma linha importante está faltando. impedindo o funcionamento correto.

# %%
def ler_numeros():
    a = int(input("Digite o primeiro número: "))
    b = int(input("Digite o segundo número: "))
    return a, b

def exibir_soma():
    #LINHA FALTANDO AQUI

    print("A soma dos números é:", a + b)

#Chamada principal
exibir_soma()

# %% [markdown]
# ### Escreva a linha de código que deve **substituir # LINHA FALTANDO AQUI** para que a função **exibir_soma()** funcione corretamente usando os valores da função **ler_numeros().**
