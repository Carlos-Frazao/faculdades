# %% [markdown]
# ### 05. Uma empresa desenvolvendo de tecnologia um educacional está de sistema mensagens automatizadas para uma plataforma de ensino. Ο objetivo é exibir mensagens diferentes dependendo do status do usuário (autenticado ou não). Para manter o código organizado e reutilizável, a equipe optou por utilizar **funções**.
#
# ### Um dos estagiários escreveu o seguinte código:

# %%
mensagem = "Bem-vindo(a)!"

def alterar_mensagem(): mensagem = "Acesso negado."

def mostrar_mensagem():
    print(mensagem)

alterar_mensagem()
mostrar_mensagem()

# %% [markdown]
# ### Com base no conceito de funções em Python e no escopo de variáveis, analise as afirmativas a seguir
#
# + ### I. A função alterar_mensagem() não modifica a variável mensagem global, pois cria uma nova variável local com o mesmo nome.
#
# + ### II. A função mostrar_mensagem() altera e imprime o valor da variável mensagem definida no escopo global.
#
# + ### III. Para que a função alterar_mensagem() modifique de fato o valor da variável global, seria necessário usar a palavra-chave global dentro da função. C
#
# ### Assinale a alternativa correta:
#
# ### A) Apenas le ll estão corretas.
#
# ### B) Apenas I e III estão corretas.
#
# ### C) Apenas Il e III estão corretas.
#
# ### D) Todas estão corretas.
#
# ### E) Nenhuma está correta.
#
# ### **Respostas corretas: (B)**
